# %%
from scholarly import scholarly
search_query = scholarly.search_single_pub('Galvanization of protein–protein interactions in a dynamic zinc interactome')
search_query['num_citations']
# Out:
# "@article{kocyla2021galvanization,\n abstract = {The presence of Zn 2+ at protein–protein interfaces modulates complex function, stability, and introduces structural flexibility/complexity, chemical selectivity, and reversibility driven in a Zn 2+-dependent manner. Recent studies have demonstrated that dynamically changing Zn 2+ affects numerous cellular processes, including protein–protein communication and protein complex assembly. How Zn 2+-involved protein–protein interactions (ZPPIs) are formed and dissociate and how their stability and reactivity are driven in a zinc interactome},\n author = {Kocy{\\l}a, Anna and Tran, J{\\'o}zef Ba and Kr{\\k{e}}{\\.z}el, Artur},\n journal = {Trends in Biochemical Sciences},\n number = {1},\n pages = {64--79},\n pub_year = {2021},\n publisher = {Elsevier},\n title = {Galvanization of protein--protein interactions in a dynamic zinc interactome},\n venue = {Trends in Biochemical Sciences},\n volume = {46}\n}\n"

# %%
from scholarly import scholarly


num2words = {1: 'one',
             2: 'two',
             3: 'three',
             4: 'four',
             5: 'five',
             6: 'six',
             7: 'seven',
             8: 'eight',
             9: 'nine',
             10: 'ten',
             11: 'eleven',
             12: 'twelve',
             13: 'thirteen',
             14: 'fourteen',
             15: 'fifteen',
             16: 'sixteen',
             17: 'seventeen',
             18: 'eighteen',
             19: 'nineteen',
             20: 'twenty',
             30: 'thirty',
             40: 'forty',
             50: 'fifty',
             60: 'sixty',
             70: 'seventy',
             80: 'eighty',
             90: 'ninety',
             0: 'zero'}


def n2w(n):
    try:
        return (num2words[n])
    except KeyError:
        try:
            return ((num2words[n-n % 10]) + ' ' + (num2words[n % 10].lower()))
        except KeyError:
            return ('Number out of range')


search_query = scholarly.search_single_pub(
    'Relations between Structure and Zn (II) Binding Affinity Shed Light on the Mechanisms of Rad50 Hook Domain Functioning and Its Phosphorylation')

num_citations = search_query['num_citations']

if num_citations == 0:
    print(', and though the article was not cited yet (as of \\today), it gives a solid fundations for the disscussion of unique properties of the zinc hook from \\gls{sc} \\gls{rad}.')
elif num_citations > 0:
    if num_citations <= 10:
        print(f'. The article was cited by {n2w(num_citations)} other articles so far (as of \\today).')
    else:
        print(f'. The article was cited by {num_citations} other articles so far (as of \\today).')
# Out:
# . The article is cited by nine other articles so far (as of \today).

# %%
from scholarly import scholarly


num2words = {1: 'one',
             2: 'two',
             3: 'three',
             4: 'four',
             5: 'five',
             6: 'six',
             7: 'seven',
             8: 'eight',
             9: 'nine',
             10: 'ten',
             11: 'eleven',
             12: 'twelve',
             13: 'thirteen',
             14: 'fourteen',
             15: 'fifteen',
             16: 'sixteen',
             17: 'seventeen',
             18: 'eighteen',
             19: 'nineteen',
             20: 'twenty',
             30: 'thirty',
             40: 'forty',
             50: 'fifty',
             60: 'sixty',
             70: 'seventy',
             80: 'eighty',
             90: 'ninety',
             0: 'zero'}


def n2w(n):
    try:
        return (num2words[n])
    except KeyError:
        try:
            return ((num2words[n-n % 10]) + ' ' + (num2words[n % 10].lower()))
        except KeyError:
            return ('Number out of range')


search_query = scholarly.search_single_pub(
    'Chapter 6 Galvanization of Protein-Protein Interactions in a Dynamic Zinc Interactome')

num_citations = search_query['num_citations']

if num_citations <= 10:
    print(f'The article was warmly recieved in the scientific community and was cited by {n2w(num_citations)} other articles so far (as of \\today).')
else:
    print(f'The article was warmly recieved in the scientific community and was cited by {num_citations} other articles so far (as of \\today).')
# Out:
# The article was warmly recieved in the scientific community and was cited by 20 other articles so far (as of \today).

# %%
from scholarly import scholarly

num2words = {1: 'one',
             2: 'two',
             3: 'three',
             4: 'four',
             5: 'five',
             6: 'six',
             7: 'seven',
             8: 'eight',
             9: 'nine',
             10: 'ten',
             11: 'eleven',
             12: 'twelve',
             13: 'thirteen',
             14: 'fourteen',
             15: 'fifteen',
             16: 'sixteen',
             17: 'seventeen',
             18: 'eighteen',
             19: 'nineteen',
             20: 'twenty',
             30: 'thirty',
             40: 'forty',
             50: 'fifty',
             60: 'sixty',
             70: 'seventy',
             80: 'eighty',
             90: 'ninety',
             0: 'zero'}


def n2w(n):
    try:
        return (num2words[n])
    except KeyError:
        try:
            return ((num2words[n-n % 10]) + ' ' + (num2words[n % 10].lower()))
        except KeyError:
            return ('Number out of range')


search_query = scholarly.search_single_pub(
    'InterMetalDB: A Database and Browser of Intermolecular Metal Binding Sites in Macromolecules with Structural Information')

num_citations = search_query['num_citations']

if num_citations <= 10:
    print(f' {n2w(num_citations)} times as of \\today.')
else:
    print( '{num_citations} times as of \\today.')
# Out:
# {num_citations} times as of \today.

# %%
from scholarly import scholarly

num2words = {1: 'once',
             2: 'two',
             3: 'three',
             4: 'four',
             5: 'five',
             6: 'six',
             7: 'seven',
             8: 'eight',
             9: 'nine',
             10: 'ten',
             11: 'eleven',
             12: 'twelve',
             13: 'thirteen',
             14: 'fourteen',
             15: 'fifteen',
             16: 'sixteen',
             17: 'seventeen',
             18: 'eighteen',
             19: 'nineteen',
             20: 'twenty',
             30: 'thirty',
             40: 'forty',
             50: 'fifty',
             60: 'sixty',
             70: 'seventy',
             80: 'eighty',
             90: 'ninety',
             0: 'zero'}


def n2w(n):
    try:
        return (num2words[n])
    except KeyError:
        try:
            return ((num2words[n-n % 10]) + ' ' + (num2words[n % 10].lower()))
        except KeyError:
            return ('Number out of range')


search_query = scholarly.search_single_pub(
    'An Extremely Stable Interprotein Tetrahedral Hg(Cys)4 Forms in the Zinc Hook Domain of Rad50 Protein at Physiological pH')

num_citations = search_query['num_citations']

if num_citations <= 10:
    if num_citations == 1:
        print(f'So far the article was cited {n2w(num_citations)} (as of \\today).')
    else:
        print(f'So far the article was cited {n2w(num_citations)} times (as of \\today).')

else:
    print(f'The article was warmly recieved in the scientific community and was cited by {num_citations} other articles so far (as of \\today).')
# Out:
#   Cell In[3], line 49
#     if == 1:
#        ^
# SyntaxError: invalid syntax

# %%
from scholarly import scholarly


num2words = {1: 'one',
             2: 'two',
             3: 'three',
             4: 'four',
             5: 'five',
             6: 'six',
             7: 'seven',
             8: 'eight',
             9: 'nine',
             10: 'ten',
             11: 'eleven',
             12: 'twelve',
             13: 'thirteen',
             14: 'fourteen',
             15: 'fifteen',
             16: 'sixteen',
             17: 'seventeen',
             18: 'eighteen',
             19: 'nineteen',
             20: 'twenty',
             30: 'thirty',
             40: 'forty',
             50: 'fifty',
             60: 'sixty',
             70: 'seventy',
             80: 'eighty',
             90: 'ninety',
             0: 'zero'}


def n2w(n):
    try:
        return (num2words[n])
    except KeyError:
        try:
            return ((num2words[n-n % 10]) + ' ' + (num2words[n % 10].lower()))
        except KeyError:
            return ('Number out of range')


search_query = scholarly.search_single_pub(
    'Relations between Structure and Zn (II) Binding Affinity Shed Light on the Mechanisms of Rad50 Hook Domain Functioning and Its Phosphorylation')

num_citations = search_query['num_citations']

if num_citations == 0:
    print(', and though the article was not cited yet (as of \\today),\\footnote{\\url{https://scholar.google.com/}} it gives a solid fundations for the disscussion of unique properties of the zinc hook from \\gls{sc} \\gls{rad}.')
elif num_citations > 0:
    if num_citations <= 10:
        print(f'. The article was cited by {n2w(num_citations)} other articles so far (as of \\today).')
    else:
        print(f'. The article was cited by {num_citations} other articles so far (as of \\today).''\\footnote{\\url{https://scholar.google.com/}}')
# Out:
# , and though the article was not cited yet (as of \today),\footnote{\url{https://scholar.google.com/}} it gives a solid fundations for the disscussion of unique properties of the zinc hook from \gls{sc} \gls{rad}.
